# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
import json
import glob
import re
import nltk
import sklearn
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from tensorflow import keras
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Lambda, Layer
from tensorflow.keras.models import Model, load_model, model_from_json
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn import datasets
from pathlib import Path

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
os.chdir('/gdrive/My Drive/drivebuddy_text_classification')

with open('dataset/pavbhaji.json', 'r') as f:
    data = json.load(f)

# %%
# indexing json data with filename
indexed_data = {d['display_url'].split('/')[-1]: d['edge_media_to_caption']['edges'][0]['node']['text'] for d in data if d['edge_media_to_caption']['edges']}

# %%
file_names0_set = set([f.split('/')[-1] for f in glob.glob('dataset_mod/images/0/*.jpg')])
file_names1_set = set([f.split('/')[-1] for f in glob.glob('dataset_mod/images/1/*.jpg')])

# %%
# dataframe with columns (filename, text, label)
data_with_labels = pd.DataFrame([{'name': name, 'text': indexed_data[name], 'label': 1 if name in file_names1_set else 0} for name in file_names0_set | file_names1_set])

# %%
data_with_labels.head()
# Out:
#                                                 name  ... label
# 0  39392437_1855433301206753_3077607271769833472_...  ...     0
# 1  39399778_319114562170341_3160868167740293120_n...  ...     0
# 2  39400565_2145822319073330_7701035855338536960_...  ...     1
# 3  39175550_324648548281295_6429935512378671104_n...  ...     0
# 4  39294744_1228134780656766_2536114897649926144_...  ...     1
#
# [5 rows x 3 columns]

# %%
# preprocessing function

def filter_query(query):
    query = query.lower()
    query = re.sub(r'[@][^\s]+', '', query) #remove @mentions
    query = re.sub(r'pav.{0,3}bhaji', ' pavbhaji ', query) #replace all variations of pavbhaji with "pavbhaji"
    query = re.sub(r'[\!-\/\:-\@]+', ' ', query) 
    query = re.sub('[^A-Za-z0-9\s]+', ' ', query) #remove all characters except alphanumeric
    query = re.sub(r'[\t\n\r\f ]+', ' ', re.sub(r'\.', '. ', query)) #replace multiple spaces with a single space
    query = ' '.join([w for w in query.split() if w not in stopwords.words('english')]) #remove stopwords
    
    # print (query)
    # doc = nlp(query)
    # tokens = [lemmatizer.lemmatize(t) for t in tokens]
    # filt_q = ' '.join(tokens)
    filt_q = re.sub(r'\b(n\'t|nt)\b', 'not', query)
    filt_q = re.sub(r'\'ll\b', 'will', filt_q)
    return filt_q

# %%
processed_text = data_with_labels['text'].map(filter_query)
df = pd.DataFrame({'name':data_with_labels['name'], 'text':processed_text, 'label': data_with_labels['label']})

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.2)

# %%
category_counts = len(np.unique(df.label))
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
embed = hub.load(module_url)
embed.graph_debug_info
# embed_size = embed.get_output_info_dict()['default'].get_shape()[1].value
# Out:
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d0fed9560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d0fed9560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
class LearningRateTracker(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(" - lr: {}".format(K.eval(self.model.optimizer.lr)))

# %%
# build a model with tf_hub universal sentence encoder followed by dense network

def UniversalEmbedding(x):
    return embed(tf.squeeze(tf.cast(x, tf.string)))

input_text = Input(shape=(1,), dtype=tf.string)
embedding = Lambda(UniversalEmbedding, output_shape=(512,))(input_text)
dense1 = Dense(1024, activation='relu')(embedding)
dense2 = Dense(128, activation='relu')(dense1)
out = Dense(1, activation='sigmoid')(dense2)

model = Model(inputs=[input_text], outputs=out)

LEARNING_RATE = 0.001

optimizer = Adam(lr=LEARNING_RATE)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d114da5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d114da5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d139b8ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f1d139b8ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_11), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_11), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
# train model

LR_PATIENCE = 10
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=LR_PATIENCE, min_lr=1e-8, verbose=1, mode="min")
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
lr_tracker = LearningRateTracker()

history = model.fit(X_train, 
          y_train,
          validation_data=(X_test, y_test),
          epochs=1000,
          batch_size=256,
          callbacks=[es_callback, lr_tracker, reduce_lr])

# achieves maximum accuracy of 74.7% on validation
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 3s 588ms/step - loss: 0.6906 - accuracy: 0.4785 - val_loss: 0.6914 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 2/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.6621 - accuracy: 0.5933 - val_loss: 0.6824 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 3/1000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6385 - accuracy: 0.6081 - val_loss: 0.6533 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 4/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6169 - accuracy: 0.7316 - val_loss: 0.6367 - val_accuracy: 0.6154
#  - lr: 0.0010000000474974513
# Epoch 5/1000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5850 - accuracy: 0.7571 - val_loss: 0.6410 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 6/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5529 - accuracy: 0.7494 - val_loss: 0.6302 - val_accuracy: 0.5824
#  - lr: 0.0010000000474974513
# Epoch 7/1000
# 2/2 [==============================] - 0s 144ms/step - loss: 0.5185 - accuracy: 0.7673 - val_loss: 0.5902 - val_accuracy: 0.6813
#  - lr: 0.0010000000474974513
# Epoch 8/1000
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4781 - accuracy: 0.7833 - val_loss: 0.5821 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 9/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4498 - accuracy: 0.7823 - val_loss: 0.5959 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 10/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.4078 - accuracy: 0.8323 - val_loss: 0.5709 - val_accuracy: 0.7033
#  - lr: 0.0010000000474974513
# Epoch 11/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3739 - accuracy: 0.8201 - val_loss: 0.5612 - val_accuracy: 0.7143
#  - lr: 0.0010000000474974513
# Epoch 12/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3489 - accuracy: 0.8476 - val_loss: 0.5725 - val_accuracy: 0.6923
#  - lr: 0.0010000000474974513
# Epoch 13/1000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.3189 - accuracy: 0.8791 - val_loss: 0.5767 - val_accuracy: 0.7253
#  - lr: 0.0010000000474974513
# Epoch 14/1000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.2947 - accuracy: 0.8952 - val_loss: 0.5837 - val_accuracy: 0.7033
#  - lr: 0.0010000000474974513
# Epoch 15/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.2640 - accuracy: 0.9065 - val_loss: 0.5784 - val_accuracy: 0.7473
#  - lr: 0.0010000000474974513
# Epoch 16/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2356 - accuracy: 0.9186 - val_loss: 0.6072 - val_accuracy: 0.7253
#  - lr: 0.0010000000474974513
# Epoch 17/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.2056 - accuracy: 0.9259 - val_loss: 0.6557 - val_accuracy: 0.7033
#  - lr: 0.0010000000474974513
# Epoch 18/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1880 - accuracy: 0.9391 - val_loss: 0.6329 - val_accuracy: 0.7253
#  - lr: 0.0010000000474974513
# Epoch 19/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0275 - accuracy: 0.9969 - val_loss: 0.8646 - val_accuracy: 0.6813
#  - lr: 0.0001250000059371814
# Epoch 50/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0283 - accuracy: 0.9969 - val_loss: 0.8713 - val_accuracy: 0.6703
#  - lr: 0.0001250000059371814
# Epoch 51/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0279 - accuracy: 0.9969 - val_loss: 0.8757 - val_accuracy: 0.6703
#  - lr: 0.0001250000059371814
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 52/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0282 - accuracy: 0.9969 - val_loss: 0.8762 - val_accuracy: 0.6703
#  - lr: 6.25000029685907e-05
# Epoch 53/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0276 - accuracy: 0.9969 - val_loss: 0.8758 - val_accuracy: 0.6703
#  - lr: 6.25000029685907e-05
# Epoch 54/1000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0271 - accuracy: 0.9969 - val_loss: 0.8747 - val_accuracy: 0.6703
#  - lr: 6.25000029685907e-05
# Epoch 55/1000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0270 - accuracy: 0.9969 - val_loss: 0.8727 - val_accuracy: 0.6813
#  - lr: 6.25000029685907e-05
# Epoch 56/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0263 - accuracy: 0.9982 - val_loss: 0.8722 - val_accuracy: 0.6813
#  - lr: 6.25000029685907e-05
# Epoch 57/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0266 - accuracy: 0.9969 - val_loss: 0.8720 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 58/1000
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0255 - accuracy: 0.9982 - val_loss: 0.8728 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 59/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0250 - accuracy: 0.9969 - val_loss: 0.8739 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 60/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0262 - accuracy: 0.9969 - val_loss: 0.8767 - val_accuracy: 0.6703
#  - lr: 6.25000029685907e-05
# Epoch 61/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0262 - accuracy: 0.9969 - val_loss: 0.8797 - val_accuracy: 0.6703
#  - lr: 6.25000029685907e-05
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 00061: early stopping

# %%
# variation with lesser units in dense network

def UniversalEmbedding(x):
    return embed(tf.squeeze(tf.cast(x, tf.string)))

input_text = Input(shape=(1,), dtype=tf.string)
embedding = Lambda(UniversalEmbedding, output_shape=(512,))(input_text)
dense1 = Dense(256, activation='relu')(embedding)
dense2 = Dense(128, activation='relu')(dense1)
out = Dense(1, activation='sigmoid')(dense2)

model = Model(inputs=[input_text], outputs=out)

LEARNING_RATE = 0.001

optimizer = Adam(lr=LEARNING_RATE)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_13), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_13), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
LR_PATIENCE = 10
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=LR_PATIENCE, min_lr=1e-8, verbose=1, mode="min")
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
lr_tracker = LearningRateTracker()

history = model.fit(X_train, 
          y_train,
          validation_data=(X_test, y_test),
          epochs=1000,
          batch_size=256,
          callbacks=[es_callback, lr_tracker, reduce_lr])

# achieves maximum accuracy of 76.92% on validation set
# Out:
# Epoch 1/1000
# 2/2 [==============================] -
1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0618 - accuracy: 0.9919 - val_loss: 0.7681 - val_accuracy: 0.6813
#  - lr: 6.25000029685907e-05
# Epoch 69/1000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0650 - accuracy: 0.9906 - val_loss: 0.7679 - val_accuracy: 0.6813
#  - lr: 6.25000029685907e-05
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 00069: early stopping

# %%
# another variation
input_text = Input(shape=(1,), dtype=tf.string)
embedding = Lambda(UniversalEmbedding, output_shape=(512,))(input_text)
dense1 = Dense(32, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(embedding)
dense2 = Dense(16, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(dense1)
out = Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(1e-4))(dense2)

model = Model(inputs=[input_text], outputs=out)

LEARNING_RATE = 0.001

optimizer = Adam(lr=LEARNING_RATE)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_15), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_15), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_26:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_27:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_28:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_29:0' shape=(26667, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_0/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_0:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_1:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_2:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_3:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_4:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_5:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_6:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_7:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_8:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_9:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_10:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_11:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_12:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_13:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_14:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_15:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_16:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_17:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_18:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_19:0' shape=(11, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_20:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_21:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_22:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_23:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_24:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_25:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_26:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_27:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_28:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_1/dense/kernel/part_29:0' shape=(10, 320) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_2/dense/kernel/part_29:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/dense/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_0:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_1:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_2:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_3:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_4:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_5:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_6:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_7:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_8:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_9:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_10:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_11:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_12:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_13:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_14:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_15:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_16:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_17:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_18:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_19:0' shape=(11, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_20:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_21:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_22:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_23:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_24:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_25:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_26:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_27:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_28:0' shape=(10, 512) dtype=float32>
#   <tf.Variable 'EncoderDNN/DNN/ResidualHidden_3/AdjustDepth/projection/kernel/part_29:0' shape=(10, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
LR_PATIENCE = 10
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=LR_PATIENCE, min_lr=1e-8, verbose=1, mode="min")
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
lr_tracker = LearningRateTracker()

history = model.fit(X_train, 
          y_train,
          validation_data=(X_test, y_test),
          epochs=1000,
          batch_size=256,
          callbacks=[es_callback, lr_tracker, reduce_lr])

# achieves accuracy of 70.33% on validation set
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 2s 530ms/step - loss: 0.7024 - accuracy: 0.4856 - val_loss: 0.7026 - val_accuracy: 0.4066
#  - lr: 0.0010000000474974513
# Epoch 2/1000
# 2/2 [==============================] - 0s 87ms/step - loss: 0.6986 - accuracy: 0.5472 - val_loss: 0.7015 - val_accuracy: 0.4945
#  - lr: 0.0010000000474974513
# Epoch 3/1000
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6955 - accuracy: 0.5731 - val_loss: 0.7004 - val_accuracy: 0.5165
#  - lr: 0.0010000000474974513
# Epoch 4/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.6930 - accuracy: 0.5798 - val_loss: 0.6997 - val_accuracy: 0.5165
#  - lr: 0.0010000000474974513
# Epoch 5/1000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.6895 - accuracy: 0.5996 - val_loss: 0.6989 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 6/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6878 - accuracy: 0.5913 - val_loss: 0.6981 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 7/1000
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6853 - accuracy: 0.5879 - val_loss: 0.6973 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 8/1000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.6814 - accuracy: 0.5944 - val_loss: 0.6963 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 9/1000
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6773 - accuracy: 0.5918 - val_loss: 0.6953 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 10/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6707 - accuracy: 0.6074 - val_loss: 0.6942 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 11/1000
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6693 - accuracy: 0.5981 - val_loss: 0.6922 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 12/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6625 - accuracy: 0.6109 - val_loss: 0.6898 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 13/1000
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6592 - accuracy: 0.6010 - val_loss: 0.6871 - val_accuracy: 0.5165
#  - lr: 0.0010000000474974513
# Epoch 14/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6520 - accuracy: 0.6204 - val_loss: 0.6844 - val_accuracy: 0.5165
#  - lr: 0.0010000000474974513
# Epoch 15/1000
# 2/2 [==============================] - 0s 92ms/step - loss: 0.6509 - accuracy: 0.6090 - val_loss: 0.6812 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 16/1000
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6419 - accuracy: 0.6322 - val_loss: 0.6787 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 17/1000
# 2/2 [==============================] - 0s 89ms/step - loss: 0.6361 - accuracy: 0.6270 - val_loss: 0.6756 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 18/1000
# 2/2 [==============================] - 0s 107ms/step - loss: 0.6313 - accuracy: 0.6520 - val_loss: 0.6718 - val_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 19/1000
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6244 - accuracy: 0.6929 - val_loss: 0.6679 - val_accuracy: 0.5055
#  - lr: 0.0010000000474974513
# Epoch 20/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6199 - accuracy: 0.6995 - val_loss: 0.6636 - val_accuracy: 0.5385
#  - lr: 0.0010000000474974513
# Epoch 21/1000
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6151 - accuracy: 0.7164 - val_loss: 0.6596 - val_accuracy: 0.5495
#  - lr: 0.0010000000474974513
# Epoch 22/1000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6044 - accuracy: 0.7279 - val_loss: 0.6568 - val_accuracy: 0.5495
#  - lr: 0.0010000000474974513
# Epoch 23/1000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5982 - accuracy: 0.7279 - val_loss: 0.6545 - val_accuracy: 0.5604
#  - lr: 0.0010000000474974513
# Epoch 24/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5930 - accuracy: 0.7271 - val_loss: 0.6511 - val_accuracy: 0.5714
#  - lr: 0.0010000000474974513
# Epoch 25/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5828 - accuracy: 0.7418 - val_loss: 0.6475 - val_accuracy: 0.5824
#  - lr: 0.0010000000474974513
# Epoch 26/1000
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5795 - accuracy: 0.7492 - val_loss: 0.6427 - val_accuracy: 0.5934
#  - lr: 0.0010000000474974513
# Epoch 27/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5706 - accuracy: 0.7668 - val_loss: 0.6382 - val_accuracy: 0.5934
#  - lr: 0.0010000000474974513
# Epoch 28/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5599 - accuracy: 0.7694 - val_loss: 0.6333 - val_accuracy: 0.6044
#  - lr: 0.0010000000474974513
# Epoch 29/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5542 - accuracy: 0.7545 - val_loss: 0.6295 - val_accuracy: 0.6154
#  - lr: 0.0010000000474974513
# Epoch 30/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5427 - accuracy: 0.7727 - val_loss: 0.6266 - val_accuracy: 0.6264
#  - lr: 0.0010000000474974513
# Epoch 31/1000
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5422 - accuracy: 0.7652 - val_loss: 0.6220 - val_accuracy: 0.6374
#  - lr: 0.0010000000474974513
# Epoch 32/1000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5312 - accuracy: 0.7623 - val_loss: 0.6183 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 33/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5219 - accuracy: 0.7712 - val_loss: 0.6162 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 34/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5160 - accuracy: 0.7754 - val_loss: 0.6151 - val_accuracy: 0.6484
#  - lr: 0.0010000000474974513
# Epoch 35/1000
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5082 - accuracy: 0.7825 - val_loss: 0.6140 - val_accuracy: 0.6484
#  - lr: 0.0010000000474974513
# Epoch 36/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4983 - accuracy: 0.7812 - val_loss: 0.6119 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 37/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4879 - accuracy: 0.8003 - val_loss: 0.6106 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 38/1000
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4852 - accuracy: 0.7847 - val_loss: 0.6093 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 39/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.4733 - accuracy: 0.7964 - val_loss: 0.6052 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 40/1000
# 2/2 [==============================] - 0s 89ms/step - loss: 0.4718 - accuracy: 0.8058 - val_loss: 0.6037 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 41/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4643 - accuracy: 0.8140 - val_loss: 0.6015 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 42/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4542 - accuracy: 0.8203 - val_loss: 0.6011 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 43/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.4510 - accuracy: 0.8093 - val_loss: 0.6013 - val_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 44/1000
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4465 - accuracy: 0.8034 - val_loss: 0.5985 - val_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch
- val_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 80/1000
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3004 - accuracy: 0.8863 - val_loss: 0.6095 - val_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 81/1000
# 2/2 [==============================] - 0s 100ms/step - loss: 0.2939 - accuracy: 0.8865 - val_loss: 0.6097 - val_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 82/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2892 - accuracy: 0.8891 - val_loss: 0.6113 - val_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 83/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2929 - accuracy: 0.8876 - val_loss: 0.6144 - val_accuracy: 0.6923
#  - lr: 0.0002500000118743628
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 84/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2877 - accuracy: 0.9017 - val_loss: 0.6159 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 85/1000
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2858 - accuracy: 0.9036 - val_loss: 0.6172 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 86/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2807 - accuracy: 0.9088 - val_loss: 0.6182 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 87/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2871 - accuracy: 0.9023 - val_loss: 0.6189 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 88/1000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.2844 - accuracy: 0.9080 - val_loss: 0.6187 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 89/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2835 - accuracy: 0.9067 - val_loss: 0.6179 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 90/1000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.2916 - accuracy: 0.8989 - val_loss: 0.6173 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 91/1000
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2823 - accuracy: 0.9086 - val_loss: 0.6169 - val_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 92/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2788 - accuracy: 0.9023 - val_loss: 0.6165 - val_accuracy: 0.6923
#  - lr: 0.0001250000059371814
# Epoch 93/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2794 - accuracy: 0.9036 - val_loss: 0.6168 - val_accuracy: 0.6923
#  - lr: 0.0001250000059371814
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 94/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2845 - accuracy: 0.8984 - val_loss: 0.6169 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 95/1000
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2852 - accuracy: 0.9010 - val_loss: 0.6168 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 96/1000
# 2/2 [==============================] - 0s 102ms/step - loss: 0.2831 - accuracy: 0.8997 - val_loss: 0.6165 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 97/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2798 - accuracy: 0.9036 - val_loss: 0.6163 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 98/1000
# 2/2 [==============================] - 0s 101ms/step - loss: 0.2836 - accuracy: 0.8997 - val_loss: 0.6163 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 99/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2833 - accuracy: 0.9023 - val_loss: 0.6163 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 100/1000
# 2/2 [==============================] - 0s 103ms/step - loss: 0.2844 - accuracy: 0.8984 - val_loss: 0.6165 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 101/1000
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2776 - accuracy: 0.9010 - val_loss: 0.6163 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 102/1000
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2847 - accuracy: 0.8997 - val_loss: 0.6161 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 103/1000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2773 - accuracy: 0.9067 - val_loss: 0.6158 - val_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 00103: early stopping

# %%
model_url = "https://tfhub.dev/google/nnlm-en-dim128/2"
# hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)
hub_layer = hub.KerasLayer(model_url, output_shape=[128], input_shape=[], 
                           dtype=tf.string, trainable=True)
# hub_layer(train_examples[:3])

model_nnlm = tf.keras.Sequential()
model_nnlm.add(hub_layer)
model_nnlm.add(tf.keras.layers.Dense(128, activation='relu'))
model_nnlm.add(tf.keras.layers.Dense(64, activation='relu'))
model_nnlm.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model_nnlm.summary()

LEARNING_RATE = 0.001

optimizer = Adam(lr=LEARNING_RATE)

model_nnlm.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['binary_accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 128)               124642688
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 124,667,521
# Trainable params: 124,667,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
LR_PATIENCE = 10
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=LR_PATIENCE, min_lr=1e-8, verbose=1, mode="min")
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
lr_tracker = LearningRateTracker()

history = model_nnlm.fit(X_train, 
          y_train,
          validation_data=(X_test, y_test),
          epochs=1000,
          batch_size=256,
          callbacks=[es_callback, lr_tracker, reduce_lr])
model_nnlm.save_weights('./model_cust_nnlm.h5')

# achieves accuracy of 71.43%
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 4s 2s/step - loss: 0.7048 - binary_accuracy: 0.4017 - val_loss: 0.6895 - val_binary_accuracy: 0.5275
#  - lr: 0.0010000000474974513
# Epoch 2/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6778 - binary_accuracy: 0.6895 - val_loss: 0.6763 - val_binary_accuracy: 0.5824
#  - lr: 0.0010000000474974513
# Epoch 3/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6582 - binary_accuracy: 0.6963 - val_loss: 0.6655 - val_binary_accuracy: 0.6044
#  - lr: 0.0010000000474974513
# Epoch 4/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6406 - binary_accuracy: 0.6899 - val_loss: 0.6557 - val_binary_accuracy: 0.5824
#  - lr: 0.0010000000474974513
# Epoch 5/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6172 - binary_accuracy: 0.7694 - val_loss: 0.6451 - val_binary_accuracy: 0.6264
#  - lr: 0.0010000000474974513
# Epoch 6/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5944 - binary_accuracy: 0.7910 - val_loss: 0.6345 - val_binary_accuracy: 0.6484
#  - lr: 0.0010000000474974513
# Epoch 7/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5660 - binary_accuracy: 0.8476 - val_loss: 0.6232 - val_binary_accuracy: 0.6813
#  - lr: 0.0010000000474974513
# Epoch 8/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5335 - binary_accuracy: 0.8739 - val_loss: 0.6106 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 9/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4961 - binary_accuracy: 0.8984 - val_loss: 0.5976 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 10/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4514 - binary_accuracy: 0.9136 - val_loss: 0.5861 - val_binary_accuracy: 0.6374
#  - lr: 0.0010000000474974513
# Epoch 11/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4034 - binary_accuracy: 0.9167 - val_loss: 0.5779 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 12/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3602 - binary_accuracy: 0.9183 - val_loss: 0.5744 - val_binary_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 13/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3079 - binary_accuracy: 0.9291 - val_loss: 0.5762 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 14/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2598 - binary_accuracy: 0.9404 - val_loss: 0.5835 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 15/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2152 - binary_accuracy: 0.9574 - val_loss: 0.5972 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 16/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1724 - binary_accuracy: 0.9630 - val_loss: 0.6173 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 17/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1373 - binary_accuracy: 0.9737 - val_loss: 0.6425 - val_binary_accuracy: 0.6703
#  - lr: 0.0010000000474974513
# Epoch 18/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1052 - binary_accuracy: 0.9819 - val_loss: 0.6710 - val_binary_accuracy: 0.6593
#  - lr: 0.0010000000474974513
# Epoch 19/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0850 - binary_accuracy: 0.9811 - val_loss: 0.7020 - val_binary_accuracy: 0.6813
#  - lr: 0.0010000000474974513
# Epoch 20/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0624 - binary_accuracy: 0.9906 - val_loss: 0.7312 - val_binary_accuracy: 0.7033
#  - lr: 0.0010000000474974513
# Epoch 21/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0484 - binary_accuracy: 0.9919 - val_loss: 0.7611 - val_binary_accuracy: 0.6923
#  - lr: 0.0010000000474974513
# Epoch 22/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0404 - binary_accuracy: 0.9906 - val_loss: 0.7888 - val_binary_accuracy: 0.6923
#  - lr: 0.0010000000474974513
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0312 - binary_accuracy: 0.9919 - val_loss: 0.8026 - val_binary_accuracy: 0.7143
#  - lr: 0.0005000000237487257
# Epoch 24/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0297 - binary_accuracy: 0.9906 - val_loss: 0.8161 - val_binary_accuracy: 0.7143
#  - lr: 0.0005000000237487257
# Epoch 25/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0279 - binary_accuracy: 0.9906 - val_loss: 0.8294 - val_binary_accuracy: 0.7033
#  - lr: 0.0005000000237487257
# Epoch 26/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0263 - binary_accuracy: 0.9906 - val_loss: 0.8425 - val_binary_accuracy: 0.7033
#  - lr: 0.0005000000237487257
# Epoch 27/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0236 - binary_accuracy: 0.9919 - val_loss: 0.8551 - val_binary_accuracy: 0.7033
#  - lr: 0.0005000000237487257
# Epoch 28/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235 - binary_accuracy: 0.9906 - val_loss: 0.8666 - val_binary_accuracy: 0.6923
#  - lr: 0.0005000000237487257
# Epoch 29/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0206 - binary_accuracy: 0.9937 - val_loss: 0.8778 - val_binary_accuracy: 0.6923
#  - lr: 0.0005000000237487257
# Epoch 30/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0174 - binary_accuracy: 0.9963 - val_loss: 0.8884 - val_binary_accuracy: 0.6923
#  - lr: 0.0005000000237487257
# Epoch 31/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0183 - binary_accuracy: 0.9937 - val_loss: 0.8992 - val_binary_accuracy: 0.6923
#  - lr: 0.0005000000237487257
# Epoch 32/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0171 - binary_accuracy: 0.9950 - val_loss: 0.9092 - val_binary_accuracy: 0.7143
#  - lr: 0.0005000000237487257
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 33/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0175 - binary_accuracy: 0.9937 - val_loss: 0.9141 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 34/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0162 - binary_accuracy: 0.9969 - val_loss: 0.9187 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 35/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0158 - binary_accuracy: 0.9969 - val_loss: 0.9229 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 36/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0165 - binary_accuracy: 0.9937 - val_loss: 0.9268 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 37/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0161 - binary_accuracy: 0.9937 - val_loss: 0.9304 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 38/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0164 - binary_accuracy: 0.9937 - val_loss: 0.9338 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 39/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0162 - binary_accuracy: 0.9937 - val_loss: 0.9368 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 40/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0152 - binary_accuracy: 0.9937 - val_loss: 0.9397 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 41/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0127 - binary_accuracy: 0.9963 - val_loss: 0.9425 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
# Epoch 42/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0138 - binary_accuracy: 0.9950 - val_loss: 0.9448 - val_binary_accuracy: 0.6923
#  - lr: 0.0002500000118743628
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 43/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0120 - binary_accuracy: 0.9963 - val_loss: 0.9462 - val_binary_accuracy: 0.6923
#  - lr: 0.0001250000059371814
# Epoch 44/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0153 - binary_accuracy: 0.9937 - val_loss: 0.9477 - val_binary_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 45/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0147 - binary_accuracy: 0.9969 - val_loss: 0.9493 - val_binary_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 46/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0121 - binary_accuracy: 0.9982 - val_loss: 0.9508 - val_binary_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 47/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0145 - binary_accuracy: 0.9969 - val_loss: 0.9523 - val_binary_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 48/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0144 - binary_accuracy: 0.9937 - val_loss: 0.9537 - val_binary_accuracy: 0.7033
#  - lr: 0.0001250000059371814
# Epoch 49/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0148 - binary_accuracy: 0.9937 - val_loss: 0.9550 - val_binary_accuracy: 0.6923
#  - lr: 0.0001250000059371814
# Epoch 50/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0142 - binary_accuracy: 0.9937 - val_loss: 0.9562 - val_binary_accuracy: 0.6923
#  - lr: 0.0001250000059371814
# Epoch 51/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0147 - binary_accuracy: 0.9937 - val_loss: 0.9573 - val_binary_accuracy: 0.6923
#  - lr: 0.0001250000059371814
# Epoch 52/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0124 - binary_accuracy: 0.9950 - val_loss: 0.9583 - val_binary_accuracy: 0.6923
#  - lr: 0.0001250000059371814
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 53/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0142 - binary_accuracy: 0.9937 - val_loss: 0.9588 - val_binary_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 54/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0143 - binary_accuracy: 0.9937 - val_loss: 0.9591 - val_binary_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 55/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0142 - binary_accuracy: 0.9937 - val_loss: 0.9594 - val_binary_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 56/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0147 - binary_accuracy: 0.9937 - val_loss: 0.9597 - val_binary_accuracy: 0.6923
#  - lr: 6.25000029685907e-05
# Epoch 57/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0146 - binary_accuracy: 0.9937 - val_loss: 0.9600 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
# Epoch 58/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0140 - binary_accuracy: 0.9937 - val_loss: 0.9603 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
# Epoch 59/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0144 - binary_accuracy: 0.9937 - val_loss: 0.9606 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
# Epoch 60/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0131 - binary_accuracy: 0.9950 - val_loss: 0.9610 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
# Epoch 61/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0124 - binary_accuracy: 0.9950 - val_loss: 0.9615 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
# Epoch 62/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0133 - binary_accuracy: 0.9950 - val_loss: 0.9620 - val_binary_accuracy: 0.7033
#  - lr: 6.25000029685907e-05
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 00062: early stopping
